# %% [markdown]
# <a href="https://colab.research.google.com/github/Roberto014/Anal-tica-de-datos-y-herramientas-de-inteligencia-artificial-II/blob/main/Act%203.5%20Regresi%C3%B3n%20Lineal%20Simple%20y%20M%C3%BAltiple/Act_3_5_Regresi%C3%B3n_Lineal_Simple_y_M%C3%BAltiple__Filtro1ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Dividir el dataframe en las 4 categorias

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Datos_limpios (4).csv")

# %%
df.head(5)
# Out:
#    Unnamed: 0 last_scraped       source  \
# 0           0   2024-06-28  city scrape
# 1           1   2024-06-27  city scrape
# 2           2   2024-06-28  city scrape
# 3           3   2024-06-28  city scrape
# 4           4   2024-06-28  city scrape
#
#                                            name host_name  host_since  \
# 0  City SkyLine View from 1 Bedroom Apt in CDMX     Marco  2013-01-21
# 1                                   Villa Dante      Dici  2010-06-28
# 2                             CONDESA HAUS  B&B  Fernando  2010-08-09
# 3            15 blocks from Paseo de la Reforma   Martina  2013-01-09
# 4             2 bedroom apt. deco bldg, Condesa  Nicholas  2011-01-04
#
#                  host_verifications host_has_profile_pic  \
# 0                ['email', 'phone']                    t
# 1  ['email', 'phone', 'work_email']                    t
# 2  ['email', 'phone', 'work_email']                    t
# 3                ['email', 'phone']                    t
# 4                ['email', 'phone']                    t
#
#   host_identity_verified neighbourhood_cleansed  ... beds   price  \
# 0                      t             Cuauhtémoc  ...  2.0  1652.0
# 1                      t  Cuajimalpa de Morelos  ...  1.0  3663.0
# 2                      t             Cuauhtémoc  ...  1.9  1477.0
# 3                      t         Miguel Hidalgo  ...  3.0   814.0
# 4                      t             Cuauhtémoc  ...  2.0  1923.0
#
#   review_scores_rating review_scores_accuracy review_scores_cleanliness  \
# 0                 4.95                   4.93                      4.95
# 1                 4.80                   4.80                      4.80
# 2                 4.58                   4.56                      4.70
# 3                 4.75                   4.83                      4.72
# 4                 4.90                   4.81                      4.75
#
#   review_scores_checkin review_scores_communication review_scores_location  \
# 0                  4.93                        4.96                   4.93
# 1                  4.80                        4.80                   4.80
# 2                  4.87                        4.78                   4.98
# 3                  4.84                        4.93                   4.46
# 4                  4.94                        4.92                   4.98
#
#   review_scores_value reviews_per_month
# 0                4.91              0.41
# 1                4.70              1.70
# 2                4.48              0.42
# 3                4.75              1.19
# 4                4.91              0.32
#
# [5 rows x 63 columns]

# %%
filtro1 = df[df["room_type"] == "Entire home/apt"]
filtro1
# Out:
#        Unnamed: 0 last_scraped       source  \
# 0               0   2024-06-28  city scrape
# 1               1   2024-06-27  city scrape
# 2               2   2024-06-28  city scrape
# 3               3   2024-06-28  city scrape
# 4               4   2024-06-28  city scrape
# ...           ...          ...          ...
# 26531       26531   2024-06-28  city scrape
# 26532       26532   2024-06-28  city scrape
# 26533       26533   2024-06-28  city scrape
# 26534       26534   2024-06-28  city scrape
# 26535       26535   2024-06-28  city scrape
#
#                                                name host_name  host_since  \
# 0      City SkyLine View from 1 Bedroom Apt in CDMX     Marco  2013-01-21
# 1                                       Villa Dante      Dici  2010-06-28
# 2                                 CONDESA HAUS  B&B  Fernando  2010-08-09
# 3                15 blocks from Paseo de la Reforma   Martina  2013-01-09
# 4                 2 bedroom apt. deco bldg, Condesa  Nicholas  2011-01-04
# ...                                             ...       ...         ...
# 26531   ¡Crystal! - 7BR Fantastic! In heart of Roma      Elvy  2014-07-31
# 26532               Iconic Suite | Terrace | View !   Nicolas  2013-07-23
# 26533         Acogedor y moderno depa en la Condesa    Sandra  2015-12-09
# 26534                    Estudio con amplia terraza   Salomon  2017-08-22
# 26535       Apt with Reforma View, Pool and Jacuzzi   HostPal  2016-04-16
#
#                      host_verifications host_has_profile_pic  \
# 0                    ['email', 'phone']                    t
# 1      ['email', 'phone', 'work_email']                    t
# 2      ['email', 'phone', 'work_email']                    t
# 3                    ['email', 'phone']                    t
# 4                    ['email', 'phone']                    t
# ...                                 ...                  ...
# 26531                ['email', 'phone']                    t
# 26532                ['email', 'phone']                    t
# 26533  ['email', 'phone', 'work_email']                    t
# 26534                ['email', 'phone']                    t
# 26535                ['email', 'phone']                    t
#
#       host_identity_verified neighbourhood_cleansed  ... beds   price  \
# 0                          t             Cuauhtémoc  ...  2.0  1652.0
# 1                          t  Cuajimalpa de Morelos  ...  1.0  3663.0
# 2                          t             Cuauhtémoc  ...  1.9  1477.0
# 3                          t         Miguel Hidalgo  ...  3.0   814.0
# 4                          t             Cuauhtémoc  ...  2.0  1923.0
# ...                      ...                    ...  ...  ...     ...
# 26531                      t             Cuauhtémoc  ...  1.9  7850.0
# 26532                      t             Cuauhtémoc  ...  2.0  1478.0
# 26533                      t             Cuauhtémoc  ...  1.0   936.0
# 26534                      t             Cuauhtémoc  ...  2.0   768.0
# 26535                      t             Cuauhtémoc  ...  2.0  1302.0
#
#       review_scores_rating review_scores_accuracy review_scores_cleanliness  \
# 0                     4.95                   4.93                      4.95
# 1                     4.80                   4.80                      4.80
# 2                     4.58                   4.56                      4.70
# 3                     4.75                   4.83                      4.72
# 4                     4.90                   4.81                      4.75
# ...                    ...                    ...                       ...
# 26531                 4.80                   4.80                      4.80
# 26532                 4.80                   4.80                      4.80
# 26533                 4.80                   4.80                      4.80
# 26534                 4.80                   4.80                      4.80
# 26535                 4.80                   4.80                      4.80
#
#       review_scores_checkin review_scores_communication  \
# 0                      4.93                        4.96
# 1                      4.80                        4.80
# 2                      4.87                        4.78
# 3                      4.84                        4.93
# 4                      4.94                        4.92
# ...                     ...                         ...
# 26531                  4.80                        4.80
# 26532                  4.80                        4.80
# 26533                  4.80                        4.80
# 26534                  4.80                        4.80
# 26535                  4.80                        4.80
#
#       review_scores_location review_scores_value reviews_per_month
# 0                       4.93                4.91              0.41
# 1                       4.80                4.70              1.70
# 2                       4.98                4.48              0.42
# 3                       4.46                4.75              1.19
# 4                       4.98                4.91              0.32
# ...                      ...                 ...               ...
# 26531                   4.80                4.70              1.70
# 26532                   4.80                4.70              1.70
# 26533                   4.80                4.70              1.70
# 26534                   4.80                4.70              1.70
# 26535                   4.80                4.70              1.70
#
# [17432 rows x 63 columns]

# %%
filtro2 = df[df["room_type"] == "Private room"]
filtro2
# Out:
#        Unnamed: 0 last_scraped           source  \
# 10             10   2024-06-28  previous scrape
# 13             13   2024-06-27      city scrape
# 14             14   2024-06-28      city scrape
# 15             15   2024-06-28      city scrape
# 17             17   2024-06-27      city scrape
# ...           ...          ...              ...
# 26510       26510   2024-06-27      city scrape
# 26514       26514   2024-06-28      city scrape
# 26515       26515   2024-06-27      city scrape
# 26519       26519   2024-06-28      city scrape
# 26529       26529   2024-06-28      city scrape
#
#                                                     name      host_name  \
# 10                                        MARIA DEL ALMA       Fernando
# 13                       OASIS IN COYOACAN, SHARED HOUSE        Edoardo
# 14                       Cool room near WTC and Metrobus         Carlos
# 15               Chilango chic: room historic Condesa DF       Citlalli
# 17                    Villa Alfonsina, Heart of Coyoacan         Héctor
# ...                                                  ...            ...
# 26510                    Habitación ideal para 1 persona           Paty
# 26514                                Habitación en Renta  Jessica Arely
# 26515                                    Habitación Majo        Mariana
# 26519  Estudio cama king con sofá cama (cocineta parc...           Said
# 26529                            Cuarto blanco iluminado        Daniela
#
#        host_since  host_verifications host_has_profile_pic  \
# 10     2011-05-31           ['phone']                    t
# 13     2012-01-28  ['email', 'phone']                    t
# 14     2011-07-13  ['email', 'phone']                    t
# 15     2014-10-10  ['email', 'phone']                    t
# 17     2013-04-10  ['email', 'phone']                    t
# ...           ...                 ...                  ...
# 26510  2015-08-16  ['email', 'phone']                    t
# 26514  2018-08-19  ['email', 'phone']                    t
# 26515  2016-12-27  ['email', 'phone']                    t
# 26519  2023-07-10  ['email', 'phone']                    t
# 26529  2016-11-13           ['phone']                    t
#
#       host_identity_verified neighbourhood_cleansed  ... beds   price  \
# 10                         f               Coyoacán  ...  1.9  1477.0
# 13                         t               Coyoacán  ...  1.0   366.0
# 14                         t          Benito Juárez  ...  1.0   315.0
# 15                         f             Cuauhtémoc  ...  1.0   898.0
# 17                         t               Coyoacán  ...  1.0  1200.0
# ...                      ...                    ...  ...  ...     ...
# 26510                      t          Benito Juárez  ...  1.0   365.0
# 26514                      t          Benito Juárez  ...  1.0   450.0
# 26515                      t      Gustavo A. Madero  ...  1.0   509.0
# 26519                      t             Cuauhtémoc  ...  2.0  1939.0
# 26529                      t         Miguel Hidalgo  ...  1.0   720.0
#
#       review_scores_rating review_scores_accuracy review_scores_cleanliness  \
# 10                    4.80                   4.80                      4.80
# 13                    4.97                   4.91                      4.91
# 14                    4.84                   4.87                      4.61
# 15                    4.83                   4.60                      4.97
# 17                    4.93                   4.94                      4.97
# ...                    ...                    ...                       ...
# 26510                 4.80                   4.80                      4.80
# 26514                 4.80                   4.80                      4.80
# 26515                 4.80                   4.80                      4.80
# 26519                 4.80                   4.80                      4.80
# 26529                 4.80                   4.80                      4.80
#
#       review_scores_checkin review_scores_communication  \
# 10                     4.80                        4.80
# 13                     4.91                        4.95
# 14                     4.98                        4.95
# 15                     4.97                        4.77
# 17                     4.96                        4.91
# ...                     ...                         ...
# 26510                  4.80                        4.80
# 26514                  4.80                        4.80
# 26515                  4.80                        4.80
# 26519                  4.80                        4.80
# 26529                  4.80                        4.80
#
#       review_scores_location review_scores_value reviews_per_month
# 10                      4.80                4.70              1.70
# 13                      4.94                4.89              0.51
# 14                      4.97                4.81              0.85
# 15                      4.93                4.73              0.22
# 17                      4.97                4.94              1.18
# ...                      ...                 ...               ...
# 26510                   4.80                4.70              1.70
# 26514                   4.80                4.70              1.70
# 26515                   4.80                4.70              1.70
# 26519                   4.80                4.70              1.70
# 26529                   4.80                4.70              1.70
#
# [8581 rows x 63 columns]

# %%
filtro3 = df[df["room_type"] == "Shared room"]
filtro3
# Out:
#        Unnamed: 0 last_scraped           source  \
# 104           104   2024-06-28  previous scrape
# 255           255   2024-06-28      city scrape
# 353           353   2024-06-27      city scrape
# 376           376   2024-06-28      city scrape
# 452           452   2024-06-28      city scrape
# ...           ...          ...              ...
# 26227       26227   2024-06-28      city scrape
# 26294       26294   2024-06-27      city scrape
# 26351       26351   2024-06-28      city scrape
# 26405       26405   2024-06-28      city scrape
# 26451       26451   2024-06-28      city scrape
#
#                                    name host_name  host_since  \
# 104     Apt near Mexico City's downtown    Andoni  2012-07-26
# 255    cuarto con terraza y uso general     Jordi  2014-05-30
# 353                       Gay UNAM Room     Andre  2015-02-05
# 376             メキシコシティの革命記念塔付近のホステルです。    Tetsuo  2015-02-22
# 452                          Nova House   Antonio  2015-04-17
# ...                                 ...       ...         ...
# 26227  Habitacion compartida en condesa   Soledad  2021-12-31
# 26294      ideal para eventos cercanos.     Laura  2023-10-15
# 26351                    Hostal mujeres   Zamaira  2016-10-25
# 26405         Habitación colonia Juárez     Julio  2016-08-30
# 26451                    Hostal hombres   Zamaira  2016-10-25
#
#                      host_verifications host_has_profile_pic  \
# 104                  ['email', 'phone']                    t
# 255                  ['email', 'phone']                    t
# 353    ['email', 'phone', 'work_email']                    t
# 376                  ['email', 'phone']                    t
# 452    ['email', 'phone', 'work_email']                    t
# ...                                 ...                  ...
# 26227                ['email', 'phone']                    t
# 26294                         ['phone']                    t
# 26351                ['email', 'phone']                    t
# 26405                ['email', 'phone']                    t
# 26451                ['email', 'phone']                    t
#
#       host_identity_verified neighbourhood_cleansed  ... beds   price  \
# 104                        f             Cuauhtémoc  ...  1.9  1477.0
# 255                        t             Cuauhtémoc  ...  2.0   640.0
# 353                        t               Coyoacán  ...  3.0   275.0
# 376                        t             Cuauhtémoc  ...  1.9   275.0
# 452                        t    Venustiano Carranza  ...  1.9   550.0
# ...                      ...                    ...  ...  ...     ...
# 26227                      t             Cuauhtémoc  ...  6.0   188.0
# 26294                      t              Iztacalco  ...  1.0   311.0
# 26351                      t          Benito Juárez  ...  6.0   210.0
# 26405                      t             Cuauhtémoc  ...  1.0   320.0
# 26451                      t          Benito Juárez  ...  6.0   210.0
#
#       review_scores_rating review_scores_accuracy review_scores_cleanliness  \
# 104                   4.80                   4.80                      4.80
# 255                   4.80                   4.80                      4.80
# 353                   5.00                   4.90                      4.70
# 376                   4.48                   4.81                      4.55
# 452                   4.85                   4.84                      4.93
# ...                    ...                    ...                       ...
# 26227                 4.80                   4.80                      4.80
# 26294                 5.00                   4.80                      4.80
# 26351                 4.80                   4.80                      4.80
# 26405                 4.00                   4.80                      4.80
# 26451                 4.80                   4.80                      4.80
#
#       review_scores_checkin review_scores_communication  \
# 104                    4.80                        4.80
# 255                    4.80                        4.80
# 353                    4.90                        5.00
# 376                    4.74                        4.74
# 452                    4.94                        4.91
# ...                     ...                         ...
# 26227                  4.80                        4.80
# 26294                  4.80                        4.80
# 26351                  4.80                        4.80
# 26405                  4.80                        4.80
# 26451                  4.80                        4.80
#
#       review_scores_location review_scores_value reviews_per_month
# 104                     4.80                4.70              1.70
# 255                     4.80                4.70              1.70
# 353                     4.70                4.80              0.10
# 376                     4.71                4.65              0.28
# 452                     4.69                4.93              0.77
# ...                      ...                 ...               ...
# 26227                   4.80                4.70              1.70
# 26294                   4.80                4.70              1.00
# 26351                   4.80                4.70              1.70
# 26405                   4.80                4.70              1.00
# 26451                   4.80                4.70              1.70
#
# [401 rows x 63 columns]

# %%
filtro4 = df[df["room_type"] == "Hotel room"]
filtro4
# Out:
#        Unnamed: 0 last_scraped           source  \
# 38             38   2024-06-28  previous scrape
# 86             86   2024-06-28      city scrape
# 90             90   2024-06-28  previous scrape
# 103           103   2024-06-28  previous scrape
# 124           124   2024-06-28  previous scrape
# ...           ...          ...              ...
# 24761       24761   2024-06-28      city scrape
# 24771       24771   2024-06-28      city scrape
# 24775       24775   2024-06-28      city scrape
# 24776       24776   2024-06-28      city scrape
# 24906       24906   2024-06-28      city scrape
#
#                                                     name          host_name  \
# 38                    COOL PENT HOUSE APARTMENT @CONDESA           Fernando
# 86     MODERN/HIP FURNISHED APARTMENT ( S1 Condesa Haus)           Fernando
# 90     Descansa en la Suite de la Abuelita San Angel ...       Martha Laura
# 103          Cómodo Estudio del Botánico, San Angel CDMX       Martha Laura
# 124                    Business Suite BEIGE near Reforma            Hermann
# ...                                                  ...                ...
# 24761     Wander Zócalo! 3 Rooms w/ Spa in Amazing Hotel  Andaz Mexico City
# 24771  4 Family Rooms w/ Heated Pool - Popocatepetl V...  Andaz Mexico City
# 24775                 Opulent Hotel Perfect for Couples!  Andaz Mexico City
# 24776   Artistic Boutique Hotel w/ Rooftop Infinity Pool  Andaz Mexico City
# 24906    Parque México District Unit! Vibrant Night Life  Andaz Mexico City
#
#        host_since                host_verifications host_has_profile_pic  \
# 38     2010-08-09  ['email', 'phone', 'work_email']                    t
# 86     2010-08-09  ['email', 'phone', 'work_email']                    t
# 90     2012-06-01  ['email', 'phone', 'work_email']                    t
# 103    2012-06-01  ['email', 'phone', 'work_email']                    t
# 124    2012-10-12                ['email', 'phone']                    t
# ...           ...                               ...                  ...
# 24761  2023-11-15                ['email', 'phone']                    t
# 24771  2023-11-15                ['email', 'phone']                    t
# 24775  2023-11-15                ['email', 'phone']                    t
# 24776  2023-11-15                ['email', 'phone']                    t
# 24906  2023-11-15                ['email', 'phone']                    t
#
#       host_identity_verified neighbourhood_cleansed  ... beds   price  \
# 38                         t             Cuauhtémoc  ...  1.9  1477.0
# 86                         t             Cuauhtémoc  ...  1.0  2808.0
# 90                         t         Álvaro Obregón  ...  1.9  1477.0
# 103                        t         Álvaro Obregón  ...  1.9  1477.0
# 124                        t             Cuauhtémoc  ...  1.9  1477.0
# ...                      ...                    ...  ...  ...     ...
# 24761                      t             Cuauhtémoc  ...  6.0  1477.0
# 24771                      t             Cuauhtémoc  ...  1.9  1477.0
# 24775                      t             Cuauhtémoc  ...  2.0  5019.0
# 24776                      t             Cuauhtémoc  ...  2.0  5294.0
# 24906                      t             Cuauhtémoc  ...  1.0  4598.0
#
#       review_scores_rating review_scores_accuracy review_scores_cleanliness  \
# 38                    4.71                   4.71                      5.00
# 86                    4.00                   5.00                      5.00
# 90                    4.96                   5.00                      5.00
# 103                   4.88                   4.84                      4.96
# 124                   4.84                   4.88                      4.84
# ...                    ...                    ...                       ...
# 24761                 4.80                   4.80                      4.80
# 24771                 4.80                   4.80                      4.80
# 24775                 4.80                   4.80                      4.80
# 24776                 4.80                   4.80                      4.80
# 24906                 4.80                   4.80                      4.80
#
#       review_scores_checkin review_scores_communication  \
# 38                     5.00                        5.00
# 86                     5.00                        4.80
# 90                     5.00                        4.96
# 103                    4.91                        4.93
# 124                    5.00                        5.00
# ...                     ...                         ...
# 24761                  4.80                        4.80
# 24771                  4.80                        4.80
# 24775                  4.80                        4.80
# 24776                  4.80                        4.80
# 24906                  4.80                        4.80
#
#       review_scores_location review_scores_value reviews_per_month
# 38                      5.00                4.86              0.06
# 86                      5.00                4.00              0.02
# 90                      4.93                4.93              0.22
# 103                     4.96                4.88              0.45
# 124                     4.84                4.80              0.18
# ...                      ...                 ...               ...
# 24761                   4.80                4.70              1.70
# 24771                   4.80                4.70              1.70
# 24775                   4.80                4.70              1.70
# 24776                   4.80                4.70              1.70
# 24906                   4.80                4.70              1.70
#
# [122 rows x 63 columns]

# %%
#Imprimimos el scatter plot entre la variable dependiente (total) e independiente (alcohol)
#Para observar el comportamiento con su dispersión
from turtle import color

sns.scatterplot(x='host_acceptance_rate', y='host_response_rate', color="blue", data=df)
#sns.scatterplot(data=df, x="alcohol", y="total", color="red", data=df)
#Alcohol tiene mejor correlacion
# Out:
# <Axes: xlabel='host_acceptance_rate', ylabel='host_response_rate'>

# %%
#Imprimimos el scatter plot entre la variable dependiente (total) e independiente (alcohol)
#Para observar el comportamiento con su dispersión
from turtle import color

sns.scatterplot(x='host_acceptance_rate', y='host_response_rate', color="blue", data=df)
#sns.scatterplot(data=df, x="alcohol", y="total", color="red", data=df)
#Alcohol tiene mejor correlacion
# Out:
# <Axes: xlabel='host_acceptance_rate', ylabel='host_response_rate'>

# %%
df6 = filtro1.groupby(['room_type'])["room_type"].count()
df6
# Out:
# room_type
# Entire home/apt    17432
# Name: room_type, dtype: int64

# %%
Vars_indep = filtro1[['host_response_rate']]
Vars_dep = filtro1['host_acceptance_rate']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
#Verificamos la función relacionada al modelo
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_indep, y=Vars_dep)
#Ya encontro la mejor ecuacion con la sumatoria del error cuadratico menor
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_response_rate'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.57408743]),
#  'rank_': 1,
#  'singular_': array([793.65517369]),
#  'intercept_': 38.86674036333637}

# %% [markdown]
# ##Modelo matemático: y= 0.57408743x + 38.86674036333637

# %%
#Predecimos los valores del total de accidentes a partir de la variable "alcohol"
#y_pred = model.predcit(X=df[['alcohol', 'speeding']])
y_pred = model.predict(X=filtro1[['host_response_rate']])
y_pred
#Toma cada registro del alcohol y esta prediciendo el valor total de accidentes
# Out:
# array([96.27548316, 93.00318482, 96.27548316, ..., 96.27548316,
#        96.27548316, 96.27548316])

# %%
#Insertamos la columna de predicciones en el Dataframe
filtro1.insert(0, 'predicciones', y_pred)

#

# %%
#Visualizamod la gráfica comparativa entre el total real y el total del parecido

sns.scatterplot(x='host_response_rate', y='predicciones', color="blue", data=filtro1)
sns.scatterplot(x='host_response_rate', y='host_acceptance_rate', color="red", data=filtro1)
#sns.lineplot(x=alcohol', y='predicciones', color="red", data=df)
# Out:
# <Axes: xlabel='host_response_rate', ylabel='predicciones'>

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo (R cuadrada)
coef_Deter = model.score(Vars_indep, Vars_dep)
coef_Deter
#
# Out:
# 0.10924676692725455

# %%
#Corroboramos cual es el coeficinete de la correlación de nuestro modelo (R)
coef_Correl = np.sqrt(coef_Deter)
coef_Correl
#
# Out:
# 0.3305249868425299

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
#Vars_indep = df[['alcohol', 'speding']]
Vars_indep = filtro1[['price']]
Vars_dep = filtro1['host_acceptance_rate']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
#Verificamos la función relacionada al modelo
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_indep, y=Vars_dep)
#Ya encontro la mejor ecuacion con la sumatoria del error cuadratico menor
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['price'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.0002079]),
#  'rank_': 1,
#  'singular_': array([165311.7494853]),
#  'intercept_': 94.58592405044377}

# %%
#Predecimos los valores del total de accidentes a partir de la variable "alcohol"
#y_pred = model.predcit(X=df[['alcohol', 'speeding']])
y_pred = model.predict(X=filtro1[['price']])
y_pred
#Toma cada registro del alcohol y esta prediciendo el valor total de accidentes
# Out:
# array([94.92937242, 95.34745637, 94.89299018, ..., 94.78051708,
#        94.74559012, 94.85660794])

# %%
#Insertamos la columna de predicciones en el Dataframe
filtro1.insert(0, 'predicciones_1', y_pred)

#

# %%
#Visualizamod la gráfica comparativa entre el total real y el total del parecido

sns.scatterplot(x='price', y='predicciones_1', color="blue", data=filtro1)
sns.scatterplot(x='price', y='host_acceptance_rate', color="red", data=filtro1)
#sns.lineplot(x=alcohol', y='predicciones', color="red", data=df)
# Out:
# <Axes: xlabel='price', ylabel='predicciones_1'>

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo (R cuadrada)
coef_Deter = model.score(Vars_indep, Vars_dep)
coef_Deter
#
# Out:
# 0.0006215829617031154

# %%
#Corroboramos cual es el coeficinete de la correlación de nuestro modelo (R)
coef_Correl = np.sqrt(coef_Deter)
coef_Correl
#
# Out:
# 0.024931565568634382

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
#Vars_indep = df[['alcohol', 'speding']]
Vars_indep = filtro1[['number_of_reviews']]
Vars_dep = filtro1['host_acceptance_rate']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
#Verificamos la función relacionada al modelo
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_indep, y=Vars_dep)
#Ya encontro la mejor ecuacion con la sumatoria del error cuadratico menor
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['number_of_reviews'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.03839309]),
#  'rank_': 1,
#  'singular_': array([6796.16317529]),
#  'intercept_': 93.31611098860452}

# %%
#Predecimos los valores del total de accidentes a partir de la variable "alcohol"
#y_pred = model.predcit(X=df[['alcohol', 'speeding']])
y_pred = model.predict(X=filtro1[['number_of_reviews']])
y_pred
#Toma cada registro del alcohol y esta prediciendo el valor total de accidentes
# Out:
# array([95.46612385, 93.31611099, 95.77326854, ..., 93.31611099,
#        93.31611099, 93.31611099])

# %%
#Insertamos la columna de predicciones en el Dataframe
filtro1.insert(0, 'predicciones_2', y_pred)

#

# %%
#Visualizamod la gráfica comparativa entre el total real y el total del parecido

sns.scatterplot(x='number_of_reviews', y='predicciones_2', color="blue", data=filtro1)
sns.scatterplot(x='number_of_reviews', y='host_acceptance_rate', color="red", data=filtro1)
#sns.lineplot(x=alcohol', y='predicciones', color="red", data=df)
# Out:
# <Axes: xlabel='number_of_reviews', ylabel='predicciones_2'>

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo (R cuadrada)
coef_Deter = model.score(Vars_indep, Vars_dep)
coef_Deter
#
# Out:
# 0.03582799233958611

# %%
#Corroboramos cual es el coeficinete de la correlación de nuestro modelo (R)
coef_Correl = np.sqrt(coef_Deter)
coef_Correl
#
# Out:
# 0.1892828368859314

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
#Vars_indep = df[['alcohol', 'speding']]
Vars_indep = filtro1[['review_scores_cleanliness']]
Vars_dep = filtro1['review_scores_location']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
#Verificamos la función relacionada al modelo
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_indep, y=Vars_dep)
#Ya encontro la mejor ecuacion con la sumatoria del error cuadratico menor
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['review_scores_cleanliness'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.19336155]),
#  'rank_': 1,
#  'singular_': array([25.63836978]),
#  'intercept_': 3.936890172264494}

# %%
#Predecimos los valores del total de accidentes a partir de la variable "alcohol"
#y_pred = model.predcit(X=df[['alcohol', 'speeding']])
y_pred = model.predict(X=filtro1[['review_scores_cleanliness']])
y_pred
#Toma cada registro del alcohol y esta prediciendo el valor total de accidentes
# Out:
# array([4.89402982, 4.86502559, 4.84568944, ..., 4.86502559, 4.86502559,
#        4.86502559])

# %%
#Insertamos la columna de predicciones en el Dataframe
filtro1.insert(0, 'predicciones_3', y_pred)

#

# %%
#Visualizamod la gráfica comparativa entre el total real y el total del parecido

sns.scatterplot(x='review_scores_cleanliness', y='review_scores_location', color="blue", data=filtro1)
sns.scatterplot(x='review_scores_cleanliness', y='predicciones_3', color="red", data=filtro1)
#sns.lineplot(x=alcohol', y='predicciones', color="red", data=df)
# Out:
# <Axes: xlabel='review_scores_cleanliness', ylabel='review_scores_location'>

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo (R cuadrada)
coef_Deter = model.score(Vars_indep, Vars_dep)
coef_Deter
#
# Out:
# 0.06743073318319048

# %%
#Corroboramos cual es el coeficinete de la correlación de nuestro modelo (R)
coef_Correl = np.sqrt(coef_Deter)
coef_Correl
#
# Out:
# 0.2596742828683474

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
#Vars_indep = df[['alcohol', 'speding']]
Vars_indep = filtro1[['number_of_reviews']]
Vars_dep = filtro1['availability_365']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
#Verificamos la función relacionada al modelo
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_indep, y=Vars_dep)
#Ya encontro la mejor ecuacion con la sumatoria del error cuadratico menor
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['number_of_reviews'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.0447422]),
#  'rank_': 1,
#  'singular_': array([6796.16317529]),
#  'intercept_': 222.35336001065096}

# %%
#Predecimos los valores del total de accidentes a partir de la variable "alcohol"
#y_pred = model.predcit(X=df[['alcohol', 'speeding']])
y_pred = model.predict(X=filtro1[['number_of_reviews']])
y_pred
#Toma cada registro del alcohol y esta prediciendo el valor total de accidentes
# Out:
# array([224.85892308, 222.35336001, 225.21686066, ..., 222.35336001,
#        222.35336001, 222.35336001])

# %%
#Insertamos la columna de predicciones en el Dataframe
filtro1.insert(0, 'predicciones_5', y_pred)

#

# %%
#Visualizamod la gráfica comparativa entre el total real y el total del parecido

sns.scatterplot(x='number_of_reviews', y='availability_365', color="blue", data=filtro1)
sns.scatterplot(x='number_of_reviews', y='predicciones_5', color="red", data=filtro1)
#sns.lineplot(x=alcohol', y='predicciones', color="red", data=df)
# Out:
# <Axes: xlabel='number_of_reviews', ylabel='availability_365'>

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo (R cuadrada)
coef_Deter = model.score(Vars_indep, Vars_dep)
coef_Deter
#
# Out:
# 0.00035553669153498557

# %%
#Corroboramos cual es el coeficinete de la correlación de nuestro modelo (R)
coef_Correl = np.sqrt(coef_Deter)
coef_Correl
#
# Out:
# 0.018855680617123997

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
#Vars_indep = df[['alcohol', 'speding']]
Vars_indep = filtro1[['review_scores_communication']]
Vars_dep = filtro1['reviews_per_month']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
#Verificamos la función relacionada al modelo
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_indep, y=Vars_dep)
#Ya encontro la mejor ecuacion con la sumatoria del error cuadratico menor
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['review_scores_communication'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.31793673]),
#  'rank_': 1,
#  'singular_': array([21.64298408]),
#  'intercept_': 0.19443620951673224}

# %%
#Predecimos los valores del total de accidentes a partir de la variable "alcohol"
#y_pred = model.predcit(X=df[['alcohol', 'speeding']])
y_pred = model.predict(X=filtro1[['review_scores_communication']])
y_pred
#Toma cada registro del alcohol y esta prediciendo el valor total de accidentes
# Out:
# array([1.7714024 , 1.72053252, 1.71417379, ..., 1.72053252, 1.72053252,
#        1.72053252])

# %%
#Insertamos la columna de predicciones en el Dataframe
filtro1.insert(0, 'predicciones_6', y_pred)

#

# %%
#Visualizamod la gráfica comparativa entre el total real y el total del parecido

sns.scatterplot(x='review_scores_communication', y='reviews_per_month', color="blue", data=filtro1)
sns.scatterplot(x='review_scores_communication', y='predicciones_6', color="red", data=filtro1)
#sns.lineplot(x=alcohol', y='predicciones', color="red", data=df)
# Out:
# <Axes: xlabel='review_scores_communication', ylabel='reviews_per_month'>

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo (R cuadrada)
coef_Deter = model.score(Vars_indep, Vars_dep)
coef_Deter
#
# Out:
# 0.0014946073990429465

# %%
#Corroboramos cual es el coeficinete de la correlación de nuestro modelo (R)
coef_Correl = np.sqrt(coef_Deter)
coef_Correl
#
# Out:
# 0.0386601525998404
