# %% [markdown]
# <a href="https://colab.research.google.com/github/Roberto014/Anal-tica-de-datos-y-herramientas-de-inteligencia-artificial-II/blob/main/ActividadBASEDEDATOSAIRNBCASITERMINADO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files
files.upload()

# %%
data=pd.read_csv("listings.csv")
data.head(5)
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0  898633  https://www.airbnb.com/rooms/898633  20240627045222   2024-06-28
# 1   35797   https://www.airbnb.com/rooms/35797  20240627045222   2024-06-27
# 2   44616   https://www.airbnb.com/rooms/44616  20240627045222   2024-06-28
# 3  913084  https://www.airbnb.com/rooms/913084  20240627045222   2024-06-28
# 4   67703   https://www.airbnb.com/rooms/67703  20240627045222   2024-06-28
#
#         source                                          name  \
# 0  city scrape  City SkyLine View from 1 Bedroom Apt in CDMX
# 1  city scrape                                   Villa Dante
# 2  city scrape                             CONDESA HAUS  B&B
# 3  city scrape            15 blocks from Paseo de la Reforma
# 4  city scrape             2 bedroom apt. deco bldg, Condesa
#
#                                          description  \
# 0  The LOCATION is undoubtedly THE BIG advantage ...
# ...

# %%
#Eliminar columnas
data.drop(columns=['host_url'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-59cce0e83d30> in <cell line: 2>()
#       1 #Eliminar columnas
# ----> 2 data.drop(columns=['host_url'], inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5342                 weight  1.0     0.8
#    5343         """
# -> 5344         return super().drop(
#    5345             labels=labels,
#    5346             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709         for axis, labels in axes.items():
#    4710             if labels is not None:
# -> 4711                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4712
#    4713         if inplace:
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26536 entries, 0 to 26535
# Data columns (total 62 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   scrape_id                                     26536 non-null  int64
#  1   last_scraped                                  26536 non-null  object
#  2   source                                        26536 non-null  object
#  3   name                                          26536 non-null  object
#  4   description                                   25585 non-null  object
#  5   host_id                                       26536 non-null  int64
#  6   host_name                                     26536 non-null  object
#  7   host_since                                    26536 non-null  object
#  8   host_location                                 20930 non-null  object
# ...

# %%
data.shape
# Out:
# (26536, 62)

# %%
valores_nulos = data2.isnull().sum()
valores_nulos
# Out:
# scrape_id                                       0
# last_scraped                                    0
# source                                          0
# name                                            0
# description                                     0
#                                                ..
# calculated_host_listings_count                  0
# calculated_host_listings_count_entire_homes     0
# calculated_host_listings_count_private_rooms    0
# calculated_host_listings_count_shared_rooms     0
# reviews_per_month                               0
# Length: 62, dtype: int64

# %%
data.head(5)
# Out:
#         scrape_id last_scraped       source  \
# 0  20240627045222   2024-06-28  city scrape
# 1  20240627045222   2024-06-27  city scrape
# 2  20240627045222   2024-06-28  city scrape
# 3  20240627045222   2024-06-28  city scrape
# 4  20240627045222   2024-06-28  city scrape
#
#                                            name  \
# 0  City SkyLine View from 1 Bedroom Apt in CDMX
# 1                                   Villa Dante
# 2                             CONDESA HAUS  B&B
# 3            15 blocks from Paseo de la Reforma
# 4             2 bedroom apt. deco bldg, Condesa
#
#                                          description  host_id host_name  \
# 0  The LOCATION is undoubtedly THE BIG advantage ...  4796027     Marco
# 1  Dentro de Villa un estudio de arte con futon, ...   153786      Dici
# 2  A new concept of hosting in mexico through a b...   196253  Fernando
# 3                                                NaN  4647293   Martina
# ...

# %% [markdown]
# ##RELLENO DE DATOS DE TIPO STRING

# %%
data2=data.copy()

# %%
data2["host_location"] =data2["host_location"].fillna("No se encuentra localizacion")

# %%
data2["description"] =data2["description"].fillna("No se encuentra la descripción")

# %%
data2["host_response_time"] =data2["host_response_time"].fillna("No se encuentra la hora")

# %%
data2["host_is_superhost"] =data2["host_is_superhost"].fillna("Desconocido")

# %%
data2["bathrooms_text"] =data2["bathrooms_text"].fillna("No hay descripción")

# %%
data2["has_availability"] =data2["has_availability"].fillna("No hay descripción")

# %%
data2["first_review"] =data2["first_review"].fillna("No hay fecha")
#first_review

# %%
data2["last_review"] =data2["last_review"].fillna("No hay fecha")
#last_review

# %% [markdown]
# ##RELLENO DE DATOS DE TIPO FLOAT O ENTERO

# %% [markdown]
# de la columna host_response_rate convierte todos los valores a valor tipo entero

# %%
data2["host_response_rate"] =data2["host_response_rate"].str.replace('%','')

# %%
data2["host_response_rate"] = data2["host_response_rate"].astype(float)

# %%
data2["host_response_rate"]=data2["host_response_rate"].fillna(round(data2["host_response_rate"].mean(),1))

# %%
data2["host_acceptance_rate"] =data2["host_acceptance_rate"].str.replace('%','')

# %%
data2["host_acceptance_rate"] = data2["host_acceptance_rate"].astype(float)

# %%
data2["host_acceptance_rate"]=data2["host_acceptance_rate"].fillna(round(data2["host_acceptance_rate"].mean(),1))

# %%
data2["bathrooms"]=data2["bathrooms"].fillna(round(data2["bathrooms"].mean(),1))

# %%
data2["bedrooms"]=data2["bedrooms"].fillna(round(data2["bedrooms"].mean(),1))

# %%
data2["beds"]=data2["beds"].fillna(round(data2["beds"].mean(),1))

# %%
data2["price"] =data2["price"].str.replace('$','')

# %%
data2["price"] =data2["price"].str.replace(',','')

# %%
data2["price"] = data2["price"].astype(float)

# %%
data2["price"]=data2["price"].fillna(round(data2["price"].mean(),1))

# %%
data = data2.groupby(['price']) ['price'].count()
data
# Out:
# price
# 105.0       1
# 109.0       1
# 119.0       2
# 125.0       2
# 134.0       1
#            ..
# 98128.0     1
# 100745.0    1
# 150000.0    1
# 274758.0    1
# 416684.0    1
# Name: price, Length: 3446, dtype: int64

# %%
data2["review_scores_rating"]=data2["review_scores_rating"].fillna(round(data2["review_scores_rating"].mean(),1))
#review_scores_rating

# %%
data2["review_scores_accuracy"]=data2["review_scores_accuracy"].fillna(round(data2["review_scores_accuracy"].mean(),1))

# %%
data2["review_scores_cleanliness"]=data2["review_scores_cleanliness"].fillna(round(data2["review_scores_cleanliness"].mean(),1))
#review_scores_cleanliness

# %%
data2["review_scores_checkin"]=data2["review_scores_checkin"].fillna(round(data2["review_scores_checkin"].mean(),1))
#review_scores_checkin

# %%
data2["review_scores_communication"]=data2["review_scores_communication"].fillna(round(data2["review_scores_communication"].mean(),1))
#review_scores_communication

# %%
data2["review_scores_location"]=data2["review_scores_location"].fillna(round(data2["review_scores_location"].mean(),1))
#review_scores_location

# %%
data2["review_scores_value"]=data2["review_scores_value"].fillna(round(data2["review_scores_value"].mean(),1))

# %%
data2["reviews_per_month"]=data2["reviews_per_month"].fillna(round(data2["reviews_per_month"].mean(),1))
#reviews_per_month

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26536 entries, 0 to 26535
# Data columns (total 62 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   scrape_id                                     26536 non-null  int64
#  1   last_scraped                                  26536 non-null  object
#  2   source                                        26536 non-null  object
#  3   name                                          26536 non-null  object
#  4   description                                   26536 non-null  object
#  5   host_id                                       26536 non-null  int64
#  6   host_name                                     26536 non-null  object
#  7   host_since                                    26536 non-null  object
#  8   host_location                                 26536 non-null  object
# ...

# %%
# Supongamos que tu DataFrame se llama 'data2'

# Paso 1: Seleccionar solo las columnas que tienen valores flotantes o enteros
columnas_numericas = data2.select_dtypes(include=['float', 'int'])

# Paso 2: Excluir algunas columnas que no quieres ver, por ejemplo, 'columna_a' y 'columna_b'
columnas_filtradas = columnas_numericas.drop(columns=['host_response_rate', 'host_acceptance_rate','bathrooms','bedrooms','beds','price','review_scores_rating','review_scores_accuracy','review_scores_cleanliness','review_scores_checkin','review_scores_communication','review_scores_location','review_scores_value','reviews_per_month'])

# Ver el resultado
print(columnas_filtradas.head())

# %%
# Supongamos que tu DataFrame se llama 'data2'

# Paso 1: Seleccionar solo las columnas que tienen valores flotantes o enteros
columnas_numericas = data2.select_dtypes(include=[object])

# Paso 2: Excluir algunas columnas que no quieres ver, por ejemplo, 'columna_a' y 'columna_b'
columnas_filtradas = columnas_numericas.drop(columns=['host_location','description','host_response_time','host_is_superhost','bathrooms_text','has_availability','first_review','last_review'])

# Ver el resultado
print(columnas_filtradas.head())
# Out:
#   last_scraped       source                                          name  \
# 0   2024-06-28  city scrape  City SkyLine View from 1 Bedroom Apt in CDMX
# 1   2024-06-27  city scrape                                   Villa Dante
# 2   2024-06-28  city scrape                             CONDESA HAUS  B&B
# 3   2024-06-28  city scrape            15 blocks from Paseo de la Reforma
# 4   2024-06-28  city scrape             2 bedroom apt. deco bldg, Condesa
#
#   host_name  host_since                host_verifications  \
# 0     Marco  2013-01-21                ['email', 'phone']
# 1      Dici  2010-06-28  ['email', 'phone', 'work_email']
# 2  Fernando  2010-08-09  ['email', 'phone', 'work_email']
# 3   Martina  2013-01-09                ['email', 'phone']
# 4  Nicholas  2011-01-04                ['email', 'phone']
#
#   host_has_profile_pic host_identity_verified neighbourhood_cleansed  \
# 0                    t                      t             Cuauhtémoc
# ...

# %% [markdown]
# ##Crear dos dataframes para ver cuales son cualitativas y cuantitativas

# %%
 #Cuantitativas de numeros
cuantitativas = data2[['scrape_id','host_id','host_response_rate','host_listings_count','host_total_listings_count','latitude','longitude','accommodates','minimum_nights','maximum_nights','minimum_minimum_nights','availability_60','availability_90','availability_365','number_of_reviews','number_of_reviews_ltm','number_of_reviews_l30d','calculated_host_listings_count','calculated_host_listings_count_entire_homes','calculated_host_listings_count_private_rooms','calculated_host_listings_count_shared_rooms','host_acceptance_rate','bathrooms','bedrooms','beds','price','review_scores_rating','review_scores_accuracy','review_scores_cleanliness','review_scores_checkin','review_scores_communication','review_scores_location','review_scores_value','reviews_per_month']]
cualitativas = data2[['last_scraped','source','name','host_name','host_since','host_verifications','host_has_profile_pic','host_identity_verified','neighbourhood_cleansed','property_type','room_type','amenities','calendar_last_scraped','instant_bookable','host_location','description','host_response_time','host_is_superhost','bathrooms_text','has_availability','first_review','last_review','host_verifications','host_has_profile_pic','host_identity_verified','neighbourhood_cleansed','bathrooms_text','amenities']]

# %%
cualitativas.info()
cuantitativas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26536 entries, 0 to 26535
# Data columns (total 28 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   last_scraped            26536 non-null  object
#  1   source                  26536 non-null  object
#  2   name                    26536 non-null  object
#  3   host_name               26536 non-null  object
#  4   host_since              26536 non-null  object
#  5   host_verifications      26536 non-null  object
#  6   host_has_profile_pic    26536 non-null  object
#  7   host_identity_verified  26536 non-null  object
#  8   neighbourhood_cleansed  26536 non-null  object
#  9   property_type           26536 non-null  object
#  10  room_type               26536 non-null  object
#  11  amenities               26536 non-null  object
#  12  calendar_last_scraped   26536 non-null  object
#  13  instant_bookable        26536 non-null  object
# ...

# %%
fig = plt.figure(figsize =(15, 8))
cuantitativas.plot(kind='box', vert=False)
plt.title("Valores Atípicos del Dataframe")
plt.show() #Dibujamos el diagrama

# %%
y = cuantitativas
limite_superior = y.mean() + 3*y.std()
limite_inferior = y.mean() - 3*y.std()
print("Limite superior permitido", limite_superior)
print("Limite inferior permitido", limite_inferior)
#Estos representan los límites que se tienen en la campana de gauss
# Out:
# Limite superior permitido scrape_id                                       2.024063e+13
# host_id                                         7.540126e+08
# host_response_rate                              1.452281e+02
# host_listings_count                             2.761162e+02
# host_total_listings_count                       4.885766e+02
# latitude                                        1.953258e+01
# longitude                                      -9.906656e+01
# accommodates                                    1.036711e+01
# minimum_nights                                  7.715870e+01
# maximum_nights                                  1.839513e+03
# minimum_minimum_nights                          7.415260e+01
# availability_60                                 1.027882e+02
# availability_90                                 1.546037e+02
# availability_365                                5.982199e+02
# number_of_reviews                               2.629871e+02
# ...

# %%
data3 = cuantitativas[(y <= limite_superior) & (y >= limite_inferior)]
data3
# Out:
#             scrape_id    host_id  host_response_rate  host_listings_count  \
# 0      20240627045222    4796027               100.0                  3.0
# 1      20240627045222     153786                 NaN                  1.0
# 2      20240627045222     196253               100.0                 17.0
# 3      20240627045222    4647293               100.0                  1.0
# 4      20240627045222     334451                89.0                  3.0
# ...               ...        ...                 ...                  ...
# 26531  20240627045222   19255745               100.0                 13.0
# 26532  20240627045222    7681206                97.0                 33.0
# 26533  20240627045222   50951150               100.0                 12.0
# 26534  20240627045222  147254250               100.0                  3.0
# 26535  20240627045222   67472234               100.0                159.0
#
#        host_total_listings_count   latitude  longitude  accommodates  \
# ...

# %%
#Corroboramos dataframes valores nulos del dataframe4 El metodo de desviacion detecta menos outliers
#Con el metodo rangointercualtilicoy el digrama de caja y bigote usa ese metodo de rangointercualitico
valores_nulos = data3.isnull().sum()
valores_nulos
# Out:
# scrape_id                                          0
# host_id                                            0
# host_response_rate                               821
# host_listings_count                              791
# host_total_listings_count                        415
# latitude                                         359
# longitude                                        702
# accommodates                                     500
# minimum_nights                                   187
# maximum_nights                                     0
# minimum_minimum_nights                           171
# availability_60                                    0
# availability_90                                    0
# availability_365                                   0
# number_of_reviews                                611
# number_of_reviews_ltm                            443
# number_of_reviews_l30d                           368
# calculated_host_listings_count                   718
# ...

# %%
#Reemplazamos valores átipicos  (nulos deldataframe con "mean")
#Realizamos una copia del dataframe
data_clean = data3.copy()
data_clean = data_clean.fillna(round(y.mean(),1))
data_clean
# Out:
#             scrape_id    host_id  host_response_rate  host_listings_count  \
# 0      20240627045222    4796027               100.0                  3.0
# 1      20240627045222     153786                94.3                  1.0
# 2      20240627045222     196253               100.0                 17.0
# 3      20240627045222    4647293               100.0                  1.0
# 4      20240627045222     334451                89.0                  3.0
# ...               ...        ...                 ...                  ...
# 26531  20240627045222   19255745               100.0                 13.0
# 26532  20240627045222    7681206                97.0                 33.0
# 26533  20240627045222   50951150               100.0                 12.0
# 26534  20240627045222  147254250               100.0                  3.0
# 26535  20240627045222   67472234               100.0                159.0
#
#        host_total_listings_count   latitude  longitude  accommodates  \
# ...
