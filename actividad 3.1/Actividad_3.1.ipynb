# %% [markdown]
# <a href="https://colab.research.google.com/github/Roberto014/Extracci-n-Datos/blob/main/actividad%203.1/Actividad_3.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Hacer el archivo de excel en un dataframe
df = pd.read_excel('Detalle precios y productos fabricados 2022.xlsx')

# %%
df.head()
# Out:
#   CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR                NOMBRE_CLIENTE  \
# 0  F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL
# 1  F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ  JUAN ANTONIO RESENDIZ UGALDE
# 2  F37041 2022-01-05   DIEGO ARMANDO LEON DURAN     ANA BARBARA CRUZ PALACIOS
# 3  F37042 2022-01-05   DIEGO ARMANDO LEON DURAN          OMAR RODRIGUEZ GOMEZ
# 4  F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL
#
#    CANT   CVE_ART                                    DESCR  PRECIO_UNITARIO  \
# 0     1  TUE00244  TUB COBRE 5/16"ØX165MM CIRCULA1.5KW127V           434.48
# 1     1  TUA00028  TUA U" 5/16 ØX250MM 1200W 120V TAP1"NPT          1264.05
# 2     7    TP0007     TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 7 MT           551.61
# 3     1    TP0001     TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 1 MT           140.00
# 4     2   BP00242  BAN P INOX 115MMX235MM 1000W 127V T/TOR           172.41
#
# ...

# %% [markdown]
# filtro 1 por objeto

# %%
filtro1 = df[df["NOMBRE_VENDEDOR"] == "LETICIA RAMIREZ HERNANDEZ"]
filtro1
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 5     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 7     F37046 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1416  F39830 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
#
#                     NOMBRE_CLIENTE  CANT       CVE_ART  \
# 0               PÚBLICO EN GENERAL     1      TUE00244
# 1     JUAN ANTONIO RESENDIZ UGALDE     1      TUA00028
# 4               PÚBLICO EN GENERAL     2       BP00242
# 5               PÚBLICO EN GENERAL     2       BP00243
# 7        ANA BARBARA CRUZ PALACIOS     3        TP0001
# ...

# %% [markdown]
# filtro por filas

# %%
Filtro2 = df.iloc[4:1424,:]
Filtro2
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 5     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 6     F37044 2022-01-05   DIEGO ARMANDO LEON DURAN
# 7     F37046 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 8     F37048 2022-01-05   DIEGO ARMANDO LEON DURAN
# ...      ...        ...                        ...
# 1419  F39833 2022-12-23         AARON NUÑO CORDOVA
# 1420  F39833 2022-12-23         AARON NUÑO CORDOVA
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
#
#                            NOMBRE_CLIENTE  CANT       CVE_ART  \
# 4                      PÚBLICO EN GENERAL     2       BP00242
# 5                      PÚBLICO EN GENERAL     2       BP00243
# 6     AIRBUS HELICOPTERS MEXICO QUERETARO     1       RP00165
# 7               ANA BARBARA CRUZ PALACIOS     3        TP0001
# ...

# %% [markdown]
# filtro 3 por filas no consecutivo

# %%
filtro3 = df.iloc[[9, 20, 40,100,200], : ]
filtro3
# Out:
#     CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 9    F37049 2022-01-05   DIEGO ARMANDO LEON DURAN
# 20   F37061 2022-01-05             ALFREDO CANELA
# 40   F37102 2022-01-12             ALFREDO CANELA
# 100  F37223 2022-01-28  LETICIA RAMIREZ HERNANDEZ
# 200  F37436 2022-02-22  LETICIA RAMIREZ HERNANDEZ
#
#                                        NOMBRE_CLIENTE  CANT   CVE_ART  \
# 9                                  FIDEICOMISO F/1596     1  TUE00207
# 20                                           ELICAMEX     3  WRE-4885
# 40                                            DEACERO     3  TUE00321
# 100  COMPONENTES ELECTRICOS Y DISPOSITIVOS ESPECIALES     1    TP0025
# 200                         ANA BARBARA CRUZ PALACIOS     2  TUA00403
#
#                                         DESCR  PRECIO_UNITARIO  \
# 9    TUB INCOLOY 1/2"Øx412mm J 9KW 240V PLACA          1615.00
# 20      BAN INOX 36MMØX25MM 150W 240V EXT30CM           496.35
# ...

# %% [markdown]
# Filtro 4 columnas consecutivas

# %%
filtro4 = df.iloc[: , :4]  #Columnas consecutivas
filtro4
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3     F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                     NOMBRE_CLIENTE
# 0               PÚBLICO EN GENERAL
# 1     JUAN ANTONIO RESENDIZ UGALDE
# 2        ANA BARBARA CRUZ PALACIOS
# 3             OMAR RODRIGUEZ GOMEZ
# 4               PÚBLICO EN GENERAL
# ...                            ...
# 1421     LUIS ENRIQUE PATIÑO PEREZ
# 1422     LUIS ENRIQUE PATIÑO PEREZ
# ...

# %% [markdown]
# filtro 5

# %%
filtro5 = df.iloc[3:5, [1,3,5]] #Columnas no consecutivas
filtro5
# Out:
#    FECHA_DOC        NOMBRE_CLIENTE  CVE_ART
# 3 2022-01-05  OMAR RODRIGUEZ GOMEZ   TP0001
# 4 2022-01-05    PÚBLICO EN GENERAL  BP00242

# %% [markdown]
# filtro 6 seleccionar index

# %%
df1 = pd.read_excel('Detalle precios y productos fabricados 2022.xlsx', index_col = 2)
#Pone la primera segunda columna como indice
df1
# Out:
#                           CVE_DOC  FECHA_DOC                NOMBRE_CLIENTE  \
# NOMBRE_VENDEDOR
# LETICIA RAMIREZ HERNANDEZ  F37034 2022-01-05            PÚBLICO EN GENERAL
# LETICIA RAMIREZ HERNANDEZ  F37036 2022-01-05  JUAN ANTONIO RESENDIZ UGALDE
# DIEGO ARMANDO LEON DURAN   F37041 2022-01-05     ANA BARBARA CRUZ PALACIOS
# DIEGO ARMANDO LEON DURAN   F37042 2022-01-05          OMAR RODRIGUEZ GOMEZ
# LETICIA RAMIREZ HERNANDEZ  F37043 2022-01-05            PÚBLICO EN GENERAL
# ...                           ...        ...                           ...
# LETICIA RAMIREZ HERNANDEZ  F39834 2022-12-23     LUIS ENRIQUE PATIÑO PEREZ
# LETICIA RAMIREZ HERNANDEZ  F39834 2022-12-23     LUIS ENRIQUE PATIÑO PEREZ
# LETICIA RAMIREZ HERNANDEZ  F39835 2022-12-23          SEVEN DAYS ALL SPORT
# LETICIA RAMIREZ HERNANDEZ  F39837 2022-12-23           REVUELTA MONTECARLO
# AARON NUÑO CORDOVA         F39838 2022-12-23                CPEG SOLUTIONS
#
#                            CANT       CVE_ART  \
# ...

# %%
#aQUI ESTA ELIGIENDO DATOS DE LA COLUMNA NOMBRE VENDEDOR
filtro6 = df1.loc[["AARON NUÑO CORDOVA", "LETICIA RAMIREZ HERNANDEZ", "DIEGO ARMANDO LEON DURAN"], ["CANT"]]
filtro6
# Out:
#                           CANT
# NOMBRE_VENDEDOR
# AARON NUÑO CORDOVA           2
# AARON NUÑO CORDOVA           8
# AARON NUÑO CORDOVA          20
# AARON NUÑO CORDOVA           2
# AARON NUÑO CORDOVA           2
# ...                        ...
# DIEGO ARMANDO LEON DURAN     5
# DIEGO ARMANDO LEON DURAN     2
# DIEGO ARMANDO LEON DURAN     3
# DIEGO ARMANDO LEON DURAN     1
# DIEGO ARMANDO LEON DURAN     1
#
# [1087 rows x 1 columns]

# %% [markdown]
# FILTRO POR CABECERA

# %%
filtro7 = df.tail(8)
filtro7
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR             NOMBRE_CLIENTE  \
# 1418  F39833 2022-12-23         AARON NUÑO CORDOVA            TRILOGIQ-MEXICO
# 1419  F39833 2022-12-23         AARON NUÑO CORDOVA            TRILOGIQ-MEXICO
# 1420  F39833 2022-12-23         AARON NUÑO CORDOVA            TRILOGIQ-MEXICO
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ  LUIS ENRIQUE PATIÑO PEREZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ  LUIS ENRIQUE PATIÑO PEREZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ       SEVEN DAYS ALL SPORT
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ        REVUELTA MONTECARLO
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA             CPEG SOLUTIONS
#
#       CANT       CVE_ART                                     DESCR  \
# 1418     2       BN00145  BAN INOX 146MMØX40MM 500W230V CINT/ALLEN
# 1419     2       BN00146   BAN INOX 9"ØX3" ANCH 1700W 230V T/CABLE
# ...

# %% [markdown]
# Filtro por comparación

# %%
#Filtro por comparación
filtro8 = df[df["PRECIO_UNITARIO"] <= 200]
filtro8
#Precios unitarios que sean menores a 200
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 3     F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 7     F37046 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 15    F37058 2022-01-05   DIEGO ARMANDO LEON DURAN
# 17    F37060 2022-01-05   DIEGO ARMANDO LEON DURAN
# ...      ...        ...                        ...
# 1319  F39621 2022-11-24  LETICIA RAMIREZ HERNANDEZ
# 1330  F39636 2022-11-25  LETICIA RAMIREZ HERNANDEZ
# 1349  F39678 2022-11-30             ALFREDO CANELA
# 1353  F39687 2022-12-05  LETICIA RAMIREZ HERNANDEZ
# 1362  F39721 2022-12-07             ALFREDO CANELA
#
#                   NOMBRE_CLIENTE  CANT       CVE_ART  \
# 3           OMAR RODRIGUEZ GOMEZ     1        TP0001
# 4             PÚBLICO EN GENERAL     2       BP00242
# 7      ANA BARBARA CRUZ PALACIOS     3        TP0001
# 15            MOLINERA DE MEXICO     5       PT00070
# 17       OSCAR VALDEZ GUADARRAMA     3  PJ31C1F1AA00
# ...

# %% [markdown]
# Filtros basicos con conectores logicos

# %%
filtro9 = df[(df["PRECIO_UNITARIO"] > 0) & (df["CVE_DOC"] == "F37042")]
filtro9
# Out:
#   CVE_DOC  FECHA_DOC           NOMBRE_VENDEDOR        NOMBRE_CLIENTE  CANT  \
# 3  F37042 2022-01-05  DIEGO ARMANDO LEON DURAN  OMAR RODRIGUEZ GOMEZ     1
#
#   CVE_ART                                 DESCR  PRECIO_UNITARIO  \
# 3  TP0001  TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 1 MT            140.0
#
#    COSTO_UNITARIO  COSTO_UNITARIO_CALCULADO  SUBTOTAL_PARTIDA  \
# 3           38.96                     38.96             140.0
#
#    COSTO_TOTAL_CALCULADO  MARGEN_UNITARIO_CALCULADO  MARGEN_TOTAL_CALCULADO
# 3                  38.96                     101.04                  101.04

# %% [markdown]
# Filtro O

# %%
#Filtro O
filtro10 = df[(df["PRECIO_UNITARIO"] > 10000) | (df["CVE_DOC"] == "F37042")]
filtro10
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 3     F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 6     F37044 2022-01-05   DIEGO ARMANDO LEON DURAN
# 40    F37102 2022-01-12             ALFREDO CANELA
# 347   F37697 2022-03-23   DIEGO ARMANDO LEON DURAN
# 373   F37734 2022-03-28   DIEGO ARMANDO LEON DURAN
# 419   F37817 2022-03-31             ALFREDO CANELA
# 479   F37933 2022-04-20  LETICIA RAMIREZ HERNANDEZ
# 558   F38097 2022-05-06             ALFREDO CANELA
# 588   F38160 2022-05-13             ALFREDO CANELA
# 655   F38315 2022-06-06         AARON NUÑO CORDOVA
# 672   F38352 2022-06-10             ALFREDO CANELA
# 842   F38648 2022-07-22  LETICIA RAMIREZ HERNANDEZ
# 851   F38665 2022-07-26   DIEGO ARMANDO LEON DURAN
# 866   F38705 2022-07-29             ALFREDO CANELA
# 931   F38850 2022-08-18  LETICIA RAMIREZ HERNANDEZ
# 960   F38910 2022-08-25             ALFREDO CANELA
# 1046  F39088 2022-09-20  LETICIA RAMIREZ HERNANDEZ
# ...

# %% [markdown]
# Filtro con not

# %%
filtro11 = df[~(df["NOMBRE_VENDEDOR"] == "DIEGO ARMANDO LEON DURAN")]#QUIERO QUE NO PONGAS ESTO
filtro11
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 5     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 7     F37046 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                     NOMBRE_CLIENTE  CANT       CVE_ART  \
# 0               PÚBLICO EN GENERAL     1      TUE00244
# 1     JUAN ANTONIO RESENDIZ UGALDE     1      TUA00028
# 4               PÚBLICO EN GENERAL     2       BP00242
# 5               PÚBLICO EN GENERAL     2       BP00243
# 7        ANA BARBARA CRUZ PALACIOS     3        TP0001
# ...

# %%
filtro11.to_csv("Entregable11.csv")

# %%
#descardar archivo filtrado en csv
from google.colab import files


files.download("Entregable11.csv")
